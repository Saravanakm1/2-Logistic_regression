# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("insurance_data.csv")
df.head(3)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1

# %%
df.shape
# Out:
# (27, 2)

# %%
#%matplotlib inline
plt.xlabel('age', fontsize=14)
plt.ylabel('bought_insurance', fontsize=14)
plt.title('Predict Insurance', fontsize=16)
plt.scatter(df.age,df.bought_insurance,color='red', marker='+' )
plt.show()

# %% [markdown]
# **Data Split**

# %%
X_train,X_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.2)

# %%
y_test
# Out:
# 19    0
# 18    0
# 9     1
# 2     1
# 23    1
# 24    1
# Name: bought_insurance, dtype: int64

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
new_data = pd.DataFrame([[50]], columns=['age'])

# %%
prediction = log_reg.predict(new_data)
prediction
# Out:
# array([1])

# %%
log_reg.score(X_test,y_test)
# Out:
# 1.0

# %%
log_reg.predict_proba(X_test)
# Out:
# array([[0.93578771, 0.06421229],
#        [0.92839839, 0.07160161],
#        [0.08743333, 0.91256667],
#        [0.3297148 , 0.6702852 ],
#        [0.38325055, 0.61674945],
#        [0.25730425, 0.74269575]])
